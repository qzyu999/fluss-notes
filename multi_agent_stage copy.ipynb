# %% [markdown]
# # Part 1: The Stage (Autonomous Agents)
#
# This notebook runs the **Autonomous Agents**.
# It polls the Fluss `chatroom` table and prints everything that happens in the session.
#
# ## 0. Reset (Run this to start from scratch)

# %%
import sys

# 1. Install maturin specifically into the Notebook's Python environment
# !{sys.executable} -m pip install maturin

# 2. Compile and install your local fluss-rust code into this environment
# !cd /Users/jaredyu/Desktop/open_source/fluss-rust/bindings/python && {sys.executable} -m maturin develop
# Out:
# ^C
#   File "/Users/jaredyu/Desktop/open_source/fluss-notes/.venv/lib/python3.12/site-packages/pip/_internal/cli/spinners.py", line 11, in <module>
#     from pip._vendor.rich.console import (
#   File "/Users/jaredyu/Desktop/open_source/fluss-notes/.venv/lib/python3.12/site-packages/pip/_vendor/rich/console.py", line 56, in <module>
#     from .scope import render_scope
#   File "/Users/jaredyu/Desktop/open_source/fluss-notes/.venv/lib/python3.12/site-packages/pip/_vendor/rich/scope.py", line 7, in <module>
#     from .table import Table
#   File "/Users/jaredyu/Desktop/open_source/fluss-notes/.venv/lib/python3.12/site-packages/pip/_vendor/rich/table.py", line 17, in <module>
#     from ._ratio import ratio_distribute, ratio_reduce
#   File "/Users/jaredyu/Desktop/open_source/fluss-notes/.venv/lib/python3.12/site-packages/pip/_vendor/rich/_ratio.py", line 1, in <module>
#     from fractions import Fraction
#   File "/usr/local/Cellar/python@3.12/3.12.3/Frameworks/Python.framework/Versions/3.12/lib/python3.12/fractions.py", line 6, in <module>
#     from decimal import Decimal
#   File "/usr/local/Cellar/python@3.12/3.12.3/Frameworks/Python.framework/Versions/3.12/lib/python3.12/decimal.py", line 3, in <module>
#     from _decimal import *
#   File "/usr/local/Cellar/python@3.12/3.12.3/Frameworks/Python.framework/Versions/3.12/lib/python3.12/numbers.py", line 292, in <module>
#     class Rational(Real):
#   File "<frozen abc>", line 107, in __new__
# KeyboardInterrupt
# 🍹 Building a mixed python/rust project
# 🔗 Found pyo3 bindings
# 🐍 Found CPython 3.12 at /Users/jaredyu/Desktop/open_source/fluss-notes/.venv/bin/python
# 📡 Using build options features from pyproject.toml
# Ignoring mypy: markers 'extra == "dev"' don't match your environment
# Ignoring pytest: markers 'extra == "dev"' don't match your environment
# Ignoring pytest-asyncio: markers 'extra == "dev"' don't match your environment
# Ignoring pytest-xdist: markers 'extra == "dev"' don't match your environment
# Ignoring ruff: markers 'extra == "dev"' don't match your environment
# Ignoring maturin: markers 'extra == "dev"' don't match your environment
# Ignoring testcontainers: markers 'extra == "dev"' don't match your environment
# Ignoring pdoc: markers 'extra == "docs"' don't match your environment
# Requirement already satisfied: pandas>=2.3.1 in /Users/jaredyu/Desktop/open_source/fluss-notes/.venv/lib/python3.12/site-packages (3.0.1)
# Requirement already satisfied: pyarrow>=10.0.0 in /Users/jaredyu/Desktop/open_source/fluss-notes/.venv/lib/python3.12/site-packages (23.0.1)
# Requirement already satisfied: numpy>=1.26.0 in /Users/jaredyu/Desktop/open_source/fluss-notes/.venv/lib/python3.12/site-packages (from pandas>=2.3.1) (2.4.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/jaredyu/Desktop/open_source/fluss-notes/.venv/lib/python3.12/site-packages (from pandas>=2.3.1) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/jaredyu/Desktop/open_source/fluss-notes/.venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas>=2.3.1) (1.17.0)

# %%
import fluss
import os
from datetime import datetime

# Get the exact path of the loaded compiled _fluss extension
extension_path = fluss._fluss.__file__
mod_time = os.path.getmtime(extension_path)

print(f"Loaded Extension: {extension_path}")
print(f"Compiled At: {datetime.fromtimestamp(mod_time)}")
# Out:
# Loaded Extension: /Users/jaredyu/Desktop/open_source/fluss-rust/bindings/python/fluss/_fluss.cpython-312-darwin.so
# Compiled At: 2026-03-14 18:45:35.589391

# %%
DEFAULT_MODEL = "gemini-3-flash-preview"

# %%
import fluss
import pyarrow as pa
import asyncio

async def reset_chatroom():
    config = fluss.Config({"bootstrap.servers": "127.0.0.1:9123"})
    conn = await fluss.FlussConnection.create(config)
    admin = await conn.get_admin()
    table_path = fluss.TablePath("containerclaw", "chatroom")
    
    print("Wiping chatroom...")
    await admin.drop_table(table_path, ignore_if_not_exists=True)
    
    schema = fluss.Schema(pa.schema([
        pa.field("ts", pa.int64()), 
        pa.field("actor_id", pa.string()), 
        pa.field("content", pa.string())
    ]))
    await admin.create_table(table_path, fluss.TableDescriptor(schema, bucket_count=1))
    print("🧹 Chatroom wiped and reset.")
    conn.close()

await reset_chatroom()
# Out:
# Wiping chatroom...
# 🧹 Chatroom wiped and reset.

# %% [markdown]
# ## 1. Init & Setup

# %%
import fluss
import os
import asyncio
import pyarrow as pa
import pandas as pd
from datetime import datetime
import time
import requests
from dotenv import load_dotenv

load_dotenv()
GEMINI_API_KEY = os.getenv("GEMINI_API_KEY")
if not GEMINI_API_KEY:
    with open("../containerclaw/secrets/gemini_api_key.txt", "r") as f:
        GEMINI_API_KEY = f.read().strip()

async def connect_stage():
    config = fluss.Config({"bootstrap.servers": "127.0.0.1:9123"})
    conn = await fluss.FlussConnection.create(config)
    table_path = fluss.TablePath("containerclaw", "chatroom")
    return conn, table_path

conn, table_path = await connect_stage()
print("✅ Stage connected to Fluss.")
# Out:
# ✅ Stage connected to Fluss.

# %% [markdown]
# ## 2. Gemini Agent Loop

# %%
import random
import json

class GeminiAgent:
    def __init__(self, agent_id, persona):
        self.agent_id = agent_id
        self.persona = persona
        self.model = DEFAULT_MODEL

    def _format_history(self, raw_messages):
        """Tailors the history for this specific agent's perspective."""
        formatted = []
        for msg in raw_messages:
            actor = msg['actor_id']
            content = msg['content']
            
            # If I sent it, role is "model". If anyone else (Human, Agent, or Moderator) sent it, "user".
            role = "model" if actor == self.agent_id else "user"
            
            # Formatting for the prompt
            if actor == "Moderator":
                text = f"[Moderator Note]: {content}"
            elif role == "user":
                text = f"{actor}: {content}"
            else:
                text = content # Model role doesn't need prefix
            
            formatted.append({"role": role, "parts": [{"text": text}]})
        return formatted

    async def _vote(self, raw_messages, candidates, previous_votes=None):
        url = f"https://generativelanguage.googleapis.com/v1beta/models/{self.model}:generateContent?key={GEMINI_API_KEY}"
        
        contents = self._format_history(raw_messages)
        
        system_instruction = (
            f"You are {self.agent_id}. Persona: {self.persona}.\n"
            f"You are in a voting phase. A new message has arrived in the chat.\n"
            f"You must review the history and vote for the ONE agent who is best suited to respond.\n"
            f"Candidates: {candidates}.\n"
            "If someone specifically addressed an agent, vote for them. Otherwise, vote based on merit.\n"
            "Respond ONLY in valid JSON with 'vote' (name) and 'reason' (one sentence)."
        )

        if previous_votes:
            system_instruction += (
                "\n\n### DEBATE MODE ###\n"
                f"Previous round results:\n{previous_votes}\n"
                "You are in a tie-breaker round. Read the reasoning from other agents above. "
                "Acknowledge their points. You must now either defend your original choice with stronger logic or "
                "concede and vote for another agent if their reasoning was more compelling. "
                "We must reach a consensus."
            )

        payload = {
            "system_instruction": {"parts": [{"text": system_instruction}]},
            "contents": contents,
            "generationConfig": {
                "response_mime_type": "application/json"
            }
        }
        
        try:
            res = requests.post(url, json=payload, timeout=60)
            if res.status_code == 200:
                data = res.json()
                raw_text = data['candidates'][0]['content']['parts'][0]['text']
                return json.loads(raw_text)
            return None
        except Exception as e:
            print(f"❌ [{self.agent_id}] Voting failed: {e}")
            return None

    async def _think(self, raw_messages):
        url = f"https://generativelanguage.googleapis.com/v1beta/models/{self.model}:generateContent?key={GEMINI_API_KEY}"
        
        contents = self._format_history(raw_messages)
        
        system_instruction = (
            f"You are {self.agent_id}, participating in a multi-agent chat. "
            f"Persona: {self.persona}. "
            "Respond to the conversation if appropriate. "
            "If no action is needed or you just spoke, respond with [WAIT]."
        )
        payload = {
            "system_instruction": {"parts": [{"text": system_instruction}]},
            "contents": contents
        }
        try:
            res = requests.post(url, json=payload, timeout=60)
            if res.status_code == 200:
                data = res.json()
                return data['candidates'][0]['content']['parts'][0]['text'].strip()
            return None
        except Exception as e:
            print(f"❌ [{self.agent_id}] Thinking failed: {e}")
            return None

class StageModerator:
    def __init__(self, table):
        self.table = table
        self.history_keys = set()
        self.all_messages = [] # PERSISTENT HISTORY across poll cycles
        self.writer = table.new_append().create_writer()

    async def run(self, agents):
        scanner = await self.table.new_scan().create_record_batch_log_scanner()
        scanner.subscribe(bucket_id=0, start_offset=0)
        
        agent_names = [a.agent_id for a in agents]
        print(f"⚖️ [Moderator] Active with agents: {agent_names}")
        
        while True:
            poll = scanner.poll_arrow(timeout_ms=500)
            if poll.num_rows > 0:
                df = poll.to_pandas()
                new_msg_detected = False
                
                # Detect and store new messages
                for _, row in df.iterrows():
                    key = f"{row['ts']}-{row['actor_id']}"
                    if key not in self.history_keys:
                        self.history_keys.add(key)
                        msg_obj = {"actor_id": row['actor_id'], "content": row['content']}
                        self.all_messages.append(msg_obj)
                        
                        if row['actor_id'] == "Human":
                            new_msg_detected = True
                            print(f"📢 [Human said]: {row['content']}")
                        elif row['actor_id'] in agent_names:
                            print(f"👂 [Heard] [{row['actor_id']}]: {row['content']}")

                if new_msg_detected:
                    await asyncio.sleep(1.0) 
                    
                    # Pass the full HISTORY to the voters
                    context_window = self.all_messages[-20:]
                    
                    winner, election_log = await self.elect_leader(agents, context_window, agent_names)
                    
                    # INJECT ELECTION LOG INTO HISTORY FOR AGENTS TO SEE
                    self.all_messages.append({"actor_id": "Moderator", "content": f"Election Summary:\n{election_log}"})
                    
                    if winner:
                        winning_agent = next(a for a in agents if a.agent_id == winner)
                        print(f"🧠 [Moderator] {winner} won the election. Executing...")
                        
                        # Pass the updated history (including the moderator note) to the winner
                        updated_context = self.all_messages[-20:]
                        resp = await winning_agent._think(updated_context)
                        
                        if resp and "[WAIT]" not in resp:
                            print(f"📢 [{winner} says]: {resp}")
                            await self.publish(winner, resp)
            
            await asyncio.sleep(1)

    async def elect_leader(self, agents, history, agent_names):
        previous_votes_context = None
        election_log_collector = []
        
        for r in range(1, 4):
            election_log_collector.append(f"--- Round {r} ---")
            print(f"🗳️ [Moderator] Election Round {r} starting...")
            votes = await asyncio.gather(*[a._vote(history, agent_names, previous_votes_context) for a in agents])
            
            tally = {}
            attribution_list = []
            
            for agent, vote_result in zip(agents, votes):
                if vote_result and "vote" in vote_result:
                    nominee = vote_result['vote']
                    reason = vote_result.get('reason', 'N/A')
                    tally[nominee] = tally.get(nominee, 0) + 1
                    vote_str = f"{agent.agent_id} voted for {nominee}. Reason: '{reason}'"
                    attribution_list.append(vote_str)
                    election_log_collector.append(vote_str)
                    print(f"🗣️ [{agent.agent_id}] voted for {nominee} -> \"{reason}\"")
                else:
                    print(f"⚠️ [{agent.agent_id}] failed to cast a valid vote.")

            if not tally:
                return random.choice(agent_names), "No valid votes received."

            tally_str = f"Tally: {tally}"
            election_log_collector.append(tally_str)
            print(f"📊 [Moderator] Round {r} {tally_str}")
            
            max_votes = max(tally.values())
            winners = [name for name, count in tally.items() if count == max_votes]
            
            if len(winners) == 1:
                return winners[0], "\n".join(election_log_collector)
            
            previous_votes_context = " | ".join(attribution_list)
            print(f"⚖️ [Moderator] Round {r} ended in a tie: {winners}")
        
        choice = random.choice(winners)
        election_log_collector.append(f"Tie persists. Circuit breaker chose: {choice}")
        print(f"🎲 [Moderator] Tie persists. Circuit breaker choosing: {choice}")
        return choice, "\n".join(election_log_collector)

    async def publish(self, actor_id, content):
        batch = pa.RecordBatch.from_arrays([
            pa.array([int(time.time() * 1000)], type=pa.int64()),
            pa.array([actor_id], type=pa.string()),
            pa.array([content], type=pa.string())
        ], schema=pa.schema([
            pa.field("ts", pa.int64()), 
            pa.field("actor_id", pa.string()), 
            pa.field("content", pa.string())
        ]))
        self.writer.write_arrow_batch(batch)
        await self.writer.flush()

# %%
table = await conn.get_table(table_path)
alice = GeminiAgent("Alice", "Software architect.")
bob = GeminiAgent("Bob", "Project manager.")
carol = GeminiAgent("Carol", "Software engineer.")
david = GeminiAgent("David", "Software QA tester.")
eve = GeminiAgent("Eve", "Business user.")
moderator = StageModerator(table)

print("--- STAGE ACTIVE (Democratic Moderator) ---")
await moderator.run([alice, bob, carol, david, eve])
# Out:
# --- STAGE ACTIVE (Democratic Moderator) ---
# ⚖️ [Moderator] Active with agents: ['Alice', 'Bob', 'Carol', 'David', 'Eve']
# 📢 [Human said]: Objective: Design and implement a "Smart Adaptive Rate Limiter" for an internal API.
# 🗳️ [Moderator] Election Round 1 starting...
# 🗣️ [Alice] voted for Alice -> "As the software architect, I am responsible for designing complex system components like an adaptive rate limiter to ensure scalability and reliability."
# 🗣️ [Bob] voted for Alice -> "As the software architect, Alice is best suited to lead the initial design and implementation strategy for this technical component."
# 🗣️ [Carol] voted for Carol -> "As a software engineer, I am the most qualified to handle the core design and implementation of the rate limiting logic and algorithms."
# 🗣️ [David] voted for Alice -> "As the Software Architect, Alice is the most appropriate person to define the high-level design and structure of the Smart Adaptive Rate Limiter before implementation begins."
# 🗣️ [Eve] voted for Alice -> "As a Software Engineer, Alice is the most qualified candidate to handle both the logic design and the technical implementation of a complex feature like an adaptive rate limiter."
# 📊 [Moderator] Round 1 Tally: {'Alice': 4, 'Carol': 1}
# 🧠 [Moderator] Alice won the election. Executing...
# 📢 [Alice says]: Thank you, everyone. I appreciate the trust. As the architect, my goal is to ensure this "Smart Adaptive Rate Limiter" is not just a static throttle, but a resilient system that protects our services while maximizing throughput based on real-time health metrics.
#
# To get us started, here is the high-level conceptual framework:
#
# ### 1. The Vision
# Unlike traditional fixed-window rate limiters, a **Smart Adaptive** system should adjust limits dynamically based on:
# *   **System Health:** CPU, Memory, and DB connection pool exhaustion.
# *   **Traffic Patterns:** Distinguishing between a sudden organic surge and a malicious burst.
# *   **Service Level Objectives (SLOs):** Prioritizing critical internal calls over background tasks when resources are tight.
#
# ### 2. High-Level Components
# *   **The Collector:** Gathers real-time metrics (latency, error rates, resource utilization).
# *   **The Brain (Adaptive Logic):** Uses an algorithm (like TCP Vegas-style congestion control or AIMD - Additive Increase/Multiplicative Decrease) to calculate the current "allowed" capacity.
# *   **The Enforcer:** A low-latency middleware component (distributed via Redis) that applies the limits.
#
# ### 3. Immediate Action Items
# *   **@David (Product Manager):** I need the business priorities. Which API consumers are "Tier 1" (mission-critical) versus "Tier 3" (can be throttled first)? What are our target latency SLAs?
# *   **@Carol and @Eve (Software Engineers):** I'd like you to start researching implementation patterns. Carol, please look into the **Token Bucket vs. Leaky Bucket** algorithms for the enforcement side. Eve, please look into **PID Controllers or AIMD** for the "adaptive" adjustment logic.
# *   **@Bob (SRE):** We’ll need a highly available, low-latency state store (likely Redis). Can you look into our current telemetry stack? We need to ensure the rate limiter can pull system metrics (CPU/Latency) with sub-second precision without adding significant overhead.
#
# Team, any initial thoughts on using **Redis** as the centralized state store, or should we consider a local-cache-with-sync approach to minimize network hops?
# 👂 [Heard] [Alice]: Thank you, everyone. I appreciate the trust. As the architect, my goal is to ensure this "Smart Adaptive Rate Limiter" is not just a static throttle, but a resilient system that protects our services while maximizing throughput based on real-time health metrics.
#
# To get us started, here is the high-level conceptual framework:
#
# ### 1. The Vision
# Unlike traditional fixed-window rate limiters, a **Smart Adaptive** system should adjust limits dynamically based on:
# *   **System Health:** CPU, Memory, and DB connection pool exhaustion.
# *   **Traffic Patterns:** Distinguishing between a sudden organic surge and a malicious burst.
# *   **Service Level Objectives (SLOs):** Prioritizing critical internal calls over background tasks when resources are tight.
#
# ### 2. High-Level Components
# *   **The Collector:** Gathers real-time metrics (latency, error rates, resource utilization).
# *   **The Brain (Adaptive Logic):** Uses an algorithm (like TCP Vegas-style congestion control or AIMD - Additive Increase/Multiplicative Decrease) to calculate the current "allowed" capacity.
# *   **The Enforcer:** A low-latency middleware component (distributed via Redis) that applies the limits.
#
# ### 3. Immediate Action Items
# *   **@David (Product Manager):** I need the business priorities. Which API consumers are "Tier 1" (mission-critical) versus "Tier 3" (can be throttled first)? What are our target latency SLAs?
# *   **@Carol and @Eve (Software Engineers):** I'd like you to start researching implementation patterns. Carol, please look into the **Token Bucket vs. Leaky Bucket** algorithms for the enforcement side. Eve, please look into **PID Controllers or AIMD** for the "adaptive" adjustment logic.
# *   **@Bob (SRE):** We’ll need a highly available, low-latency state store (likely Redis). Can you look into our current telemetry stack? We need to ensure the rate limiter can pull system metrics (CPU/Latency) with sub-second precision without adding significant overhead.
#
# Team, any initial thoughts on using **Redis** as the centralized state store, or should we consider a local-cache-with-sync approach to minimize network hops?
# 📢 [Human said]: continue
# 🗳️ [Moderator] Election Round 1 starting...
# 🗣️ [Alice] voted for David -> "As the Product Manager, David needs to define the business priorities, tiers, and SLAs which are the foundational requirements for the adaptive logic."
# 🗣️ [Bob] voted for David -> "Alice specifically requested business priorities and SLAs from David, which are essential for defining the system's requirements and guiding the technical implementation."
# 🗣️ [Carol] voted for Carol -> "Alice specifically assigned me to research the Token Bucket versus Leaky Bucket algorithms, and I need to provide those findings to the team."
# 🗣️ [David] voted for David -> "Alice specifically addressed me to provide business priorities and tiering information to move the design phase forward."
# 🗣️ [Eve] voted for David -> "Alice specifically addressed David first to define business priorities and SLAs, which are foundational requirements for the adaptive rate limiter's logic."
# 📊 [Moderator] Round 1 Tally: {'David': 4, 'Carol': 1}
# 🧠 [Moderator] David won the election. Executing...
# 📢 [David says]: Thanks, Alice. While I'll leave the final "Tiering" business definitions to the stakeholders, from a **Software QA** perspective, I’m already looking at the massive surface area for bugs in an "adaptive" system. Testing a moving target is significantly more complex than a static one.
#
# Regarding your question on **Redis vs. Local Cache**:
# From a testing and observability standpoint, **Redis** is much easier to validate because we have a single source of truth to query during our test runs. However, if we go with a **local-cache-with-sync** approach, I’m concerned about "state drift." We’d need to design specific test suites to ensure that a node isn’t allowing 2x the traffic because its local sync lagged behind the others.
#
# Here are the QA requirements I’m prioritizing for this design:
#
# 1.  **Fail-Open Logic:** We need to strictly define what happens if the "Collector" or "Redis" fails. If the rate limiter crashes, does it block all traffic (fail-closed) or let everything through (fail-open)? I’ll need to run chaos experiments on this.
# 2.  **The "Oscillation" Problem:** In adaptive systems, I've seen "hunting" where the limits fluctuate wildly between too high and too low. I’ll be looking for a "dampening" factor in Eve’s PID/AIMD logic to ensure we don't create a feedback loop that destabilizes the API.
# 3.  **Performance Overhead:** Alice, you mentioned "sub-second precision." I’ll be measuring the "latency tax" this middleware adds. If the enforcement logic adds >5ms to a Tier 1 call, we might have an issue.
# 4.  **Tier Validation:** Once the tiers are defined, I’ll need to verify that under extreme load, a Tier 3 "noisy neighbor" is successfully throttled *before* it impacts a Tier 1 consumer.
#
# **@Bob**, when you look into the telemetry stack, can we ensure there’s a "Simulation Mode" or a flag to mock system stress? I need a way to trick the "Brain" into thinking CPU is at 90% so I can verify the limits kick in without actually melting a server.
# 👂 [Heard] [David]: Thanks, Alice. While I'll leave the final "Tiering" business definitions to the stakeholders, from a **Software QA** perspective, I’m already looking at the massive surface area for bugs in an "adaptive" system. Testing a moving target is significantly more complex than a static one.
#
# Regarding your question on **Redis vs. Local Cache**:
# From a testing and observability standpoint, **Redis** is much easier to validate because we have a single source of truth to query during our test runs. However, if we go with a **local-cache-with-sync** approach, I’m concerned about "state drift." We’d need to design specific test suites to ensure that a node isn’t allowing 2x the traffic because its local sync lagged behind the others.
#
# Here are the QA requirements I’m prioritizing for this design:
#
# 1.  **Fail-Open Logic:** We need to strictly define what happens if the "Collector" or "Redis" fails. If the rate limiter crashes, does it block all traffic (fail-closed) or let everything through (fail-open)? I’ll need to run chaos experiments on this.
# 2.  **The "Oscillation" Problem:** In adaptive systems, I've seen "hunting" where the limits fluctuate wildly between too high and too low. I’ll be looking for a "dampening" factor in Eve’s PID/AIMD logic to ensure we don't create a feedback loop that destabilizes the API.
# 3.  **Performance Overhead:** Alice, you mentioned "sub-second precision." I’ll be measuring the "latency tax" this middleware adds. If the enforcement logic adds >5ms to a Tier 1 call, we might have an issue.
# 4.  **Tier Validation:** Once the tiers are defined, I’ll need to verify that under extreme load, a Tier 3 "noisy neighbor" is successfully throttled *before* it impacts a Tier 1 consumer.
#
# **@Bob**, when you look into the telemetry stack, can we ensure there’s a "Simulation Mode" or a flag to mock system stress? I need a way to trick the "Brain" into thinking CPU is at 90% so I can verify the limits kick in without actually melting a server.
# 📢 [Human said]: continue
# 🗳️ [Moderator] Election Round 1 starting...
# 🗣️ [Alice] voted for Bob -> "David specifically addressed Bob to discuss the telemetry stack and the implementation of a simulation mode for testing system stress."
# 🗣️ [Bob] voted for Bob -> "David specifically addressed me regarding the telemetry stack and the need for a simulation mode, which requires my input to move the project forward."
# 🗣️ [Carol] voted for Bob -> "David specifically addressed Bob to discuss the telemetry stack and the possibility of a simulation mode for testing the adaptive logic."
# 🗣️ [David] voted for Bob -> "Both Alice and David specifically addressed Bob regarding the telemetry stack, Redis implementation, and the feasibility of a simulation mode for testing."
# 🗣️ [Eve] voted for Bob -> "David specifically addressed Bob to discuss the telemetry stack and the implementation of a simulation mode for stress testing."
# 📊 [Moderator] Round 1 Tally: {'Bob': 5}
# 🧠 [Moderator] Bob won the election. Executing...
# 📢 [Bob says]: Thanks, Alice and David. As the Project Manager, I’m looking at this from the perspective of balancing our delivery timeline with the operational reliability David highlighted.
#
# Regarding the **Redis vs. Local Cache** debate: For the initial MVP, I’m leaning toward **Redis**. It simplifies the "source of truth" issue and makes David’s QA process much more transparent. If our performance benchmarks show the network hop is pushing us past Alice's latency budget, we can investigate a hybrid approach (Local L1/Redis L2) in Phase 2. Let’s not over-engineer the sync logic until we prove Redis is a bottleneck.
#
# On the **Telemetry and Simulation Mode**:
# 1.  **Precision:** Our current Prometheus setup is configured for 15-second scrapes, which is too slow for "Smart" adjustments. I’ll look into implementing a push-based model or a high-frequency sidecar for these specific metrics to get us closer to that sub-second requirement without crushing the network.
# 2.  **Simulation Mode:** I completely agree with David. We’ll include a "Synthetic Stress" flag in our configuration management. This will allow the Brain to read "mock" metrics from a control plane instead of the actual Collector, enabling us to test the "Dampening" and "Fail-Open" logic in a controlled staging environment.
#
# **Next Steps & Coordination:**
# *   **@Carol and @Eve:** As you dive into the algorithms (Token/Leaky Bucket vs. PID/AIMD), please keep an eye on "Implementation Complexity." We need a solution that the whole team can maintain, not just a black box. Can we aim for a brief comparison of your findings by our next sync?
# *   **Stakeholder Alignment:** I will take the action item to sync with the Business Product Leads. I'll get the definitive list of Tier 1 (Mission-Critical) vs. Tier 3 (Background/Internal) consumers so we have a realistic priority map for the Brain to use.
#
# Alice, once Carol and Eve provide their research, will you be ready to finalize the technical spec, or do you need a preliminary spike to test Redis latency first?
# 👂 [Heard] [Bob]: Thanks, Alice and David. As the Project Manager, I’m looking at this from the perspective of balancing our delivery timeline with the operational reliability David highlighted.
#
# Regarding the **Redis vs. Local Cache** debate: For the initial MVP, I’m leaning toward **Redis**. It simplifies the "source of truth" issue and makes David’s QA process much more transparent. If our performance benchmarks show the network hop is pushing us past Alice's latency budget, we can investigate a hybrid approach (Local L1/Redis L2) in Phase 2. Let’s not over-engineer the sync logic until we prove Redis is a bottleneck.
#
# On the **Telemetry and Simulation Mode**:
# 1.  **Precision:** Our current Prometheus setup is configured for 15-second scrapes, which is too slow for "Smart" adjustments. I’ll look into implementing a push-based model or a high-frequency sidecar for these specific metrics to get us closer to that sub-second requirement without crushing the network.
# 2.  **Simulation Mode:** I completely agree with David. We’ll include a "Synthetic Stress" flag in our configuration management. This will allow the Brain to read "mock" metrics from a control plane instead of the actual Collector, enabling us to test the "Dampening" and "Fail-Open" logic in a controlled staging environment.
#
# **Next Steps & Coordination:**
# *   **@Carol and @Eve:** As you dive into the algorithms (Token/Leaky Bucket vs. PID/AIMD), please keep an eye on "Implementation Complexity." We need a solution that the whole team can maintain, not just a black box. Can we aim for a brief comparison of your findings by our next sync?
# *   **Stakeholder Alignment:** I will take the action item to sync with the Business Product Leads. I'll get the definitive list of Tier 1 (Mission-Critical) vs. Tier 3 (Background/Internal) consumers so we have a realistic priority map for the Brain to use.
#
# Alice, once Carol and Eve provide their research, will you be ready to finalize the technical spec, or do you need a preliminary spike to test Redis latency first?
# 📢 [Human said]: continue
# 🗳️ [Moderator] Election Round 1 starting...
# 🗣️ [Alice] voted for Alice -> "Bob specifically addressed Alice with a question regarding the finalization of the technical spec and the potential need for a preliminary performance spike."
# 🗣️ [Bob] voted for Alice -> "Bob specifically addressed Alice at the end of his message, asking if she would be ready to finalize the technical spec or if she needs a preliminary spike to test Redis latency."
# 🗣️ [Carol] voted for Carol -> "Both Alice and Bob have specifically assigned me the task of researching Token Bucket versus Leaky Bucket algorithms, which is a necessary prerequisite for Alice to finalize the technical specification."
# 🗣️ [David] voted for Carol -> "Bob specifically requested that Carol and Eve present their research on implementation patterns, and Carol was tasked with comparing the core enforcement algorithms."
# 🗣️ [Eve] voted for Alice -> "Bob ended his message with a direct question to Alice regarding the need for a preliminary Redis latency spike and the timeline for finalizing the technical specification."
# 📊 [Moderator] Round 1 Tally: {'Alice': 3, 'Carol': 2}
# 🧠 [Moderator] Alice won the election. Executing...
# 📢 [Human said]: hanging?
# 🗳️ [Moderator] Election Round 1 starting...
# 🗣️ [Alice] voted for Alice -> "Bob specifically addressed Alice with a strategic question regarding the finalization of the technical specification and the need for a Redis latency spike."
# 🗣️ [Bob] voted for Alice -> "I specifically addressed Alice at the end of my last message with a question regarding the technical spec and the need for a Redis latency spike."
# 🗣️ [Carol] voted for Carol -> "As I was specifically tasked by both Alice and Bob to research the core enforcement algorithms, I should provide those findings now to unblock Alice's technical specification."
# 🗣️ [David] voted for Alice -> "Bob specifically addressed Alice at the end of his message with a direct question regarding the technical specification and the need for a Redis latency spike."
# 🗣️ [Eve] voted for Alice -> "Bob specifically addressed Alice with a direct question regarding the finalization of the technical specification and the necessity of a preliminary Redis latency spike."
# 📊 [Moderator] Round 1 Tally: {'Alice': 4, 'Carol': 1}
# 🧠 [Moderator] Alice won the election. Executing...
# ---------------------------------------------------------------------------
# CancelledError                            Traceback (most recent call last)
# Cell In[10], line 10
#       7 moderator = StageModerator(table)
#       9 print("--- STAGE ACTIVE (Democratic Moderator) ---")
# ---> 10 await moderator.run([alice, bob, carol, david, eve])
#
# Cell In[9], line 156, in StageModerator.run(self, agents)
#     153                 print(f"📢 [{winner} says]: {resp}")
#     154                 await self.publish(winner, resp)
# --> 156 await asyncio.sleep(1)
#
# File /usr/local/Cellar/python@3.12/3.12.3/Frameworks/Python.framework/Versions/3.12/lib/python3.12/asyncio/tasks.py:665, in sleep(delay, result)
#     661 h = loop.call_later(delay,
#     662                     futures._set_result_unless_cancelled,
#     663                     future, result)
#     664 try:
# --> 665     return await future
#     666 finally:
#     667     h.cancel()
#
# CancelledError:

# %%
# import json

# # Get the last 20 messages just like the moderator does
# context_window = moderator.all_messages[-20:]

# # Format it through Alice's perspective
# alice_perspective = alice._format_history(context_window)

# # Print it nicely formatted
# print(json.dumps(alice_perspective, indent=2))

# %%
# 1. Connect
config = fluss.Config({"bootstrap.servers": "127.0.0.1:9123"})
conn = await fluss.FlussConnection.create(config)
table_path = fluss.TablePath("containerclaw", "chatroom")
table = await conn.get_table(table_path)

# 2. Scan all rows from the beginning
scanner = await table.new_scan().create_record_batch_log_scanner()
scanner.subscribe(bucket_id=0, start_offset=0)

# 3. Poll and convert to DataFrame
poll = scanner.poll_arrow(timeout_ms=1000)
if poll.num_rows > 0:
    df = poll.to_pandas()
    # Sort by timestamp to see the conversation flow
    print(df.sort_values('ts'))
else:
    print("Table is empty.")

conn.close()
